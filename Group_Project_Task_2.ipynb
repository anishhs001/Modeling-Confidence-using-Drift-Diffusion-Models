# %%
import pandas as pd
import numpy as np

exp_data = pd.read_csv('exp_dt.csv')
exp_data
# Out:
#       rt  correct  coherent_movement_direction  coherent_orientation  \
# 0    290    False                          180                   180
# 1    471    False                            0                   180
# 2    373    False                            0                     0
# 3    389     True                            0                     0
# 4    632     True                          180                     0
# 5    459    False                          180                   180
# 6    691    False                            0                   180
# 7    354     True                          180                     0
# 8    332    False                          180                     0
# 9    643    False                          180                     0
# 10   167     True                          180                   180
# 11   674     True                          180                   180
# 12   220    False                            0                     0
# ...
